# %% [markdown]
# ![image.png](attachment:acafa5ae-e47e-4c18-a9b7-89a40d9921fc.png)

# %% [markdown]
# # Solution Template
#
# ## Empty Template to kick start A.I. Solutions
#
# #### by Joe Eberle started on 05-23-2023 - https://github.com/JoeEberle/ - josepheberle@outlook.com

# %%
import os
import schedule
from datetime import datetime
import pandas as pd 
import quick_logger as ql
import talking_code as tc 
import file_manager as fm 
import time
print(f"Libraries Imported succesfully on {datetime.now().date()} at {datetime.now().time()}")
# Out:
# Libraries Imported succesfully on 2024-10-13 at 18:21:10.970554

# %% [markdown]
# #### Required Setup Step 0 - Intitiate Configuration Settings and name the overall solution

# %%
import configparser 
config = configparser.ConfigParser()
cfg = config.read('config.ini')  
solution_name = 'solution_temple'

# %% [markdown]
# #### Required Setup Step 0 - Intitiate Logging and debugging

# %%
# Establish the Python Logger  
import logging # built in python library that does not need to be installed 
import quick_logger as ql

global start_stime 
start_time = ql.set_start_time()
logging = ql.create_logger_start(solution_name, start_time) 
ql.set_speaking_log(False)
ql.set_speaking_steps(False)
ql.pvlog('info',f'Process {solution_name} Step 0 - Initializing and starting Logging Process.')
# Out:
# Process solution_temple Step 0 - Initializing and starting Logging Process.

# %%
definition = '''
''' # Add sub content for documentation 
file_name = "solution_description.md"
with open(file_name, 'w') as f:
     f.write(definition)   # Write the template to the readme.md file

talking_code = False
if talking_code:
    tc.print_say(definition) 
else:
    print(definition)

# %%
definition = '''
''' # Add sub content for documentation 
file_name = "solution_description.md"
with open(file_name, 'a') as f:
     f.write(definition)   # Write the template to the readme.md file

talking_code = False
if talking_code:
    tc.print_say(definition) 
else:
    print(definition)

# %% [markdown]
# ## Step 0 - Process End - display log

# %%
# Calculate and classify the process performance 
status = ql.calculate_process_performance(solution_name, start_time) 
print(ql.append_log_file(solution_name))
# Out:
# 2024-10-13 18:21:11,007 - INFO - START solution_temple =============================================
# 2024-10-13 18:21:11,008 - INFO - START solution_temple Start Time = 2024-10-13 18:21:11
# 2024-10-13 18:21:11,008 - INFO - solution_temple Step 0 - Initialize the configuration file parser
# 2024-10-13 18:21:11,008 - INFO - Process solution_temple Step 0 - Initializing and starting Logging Process.
# 2024-10-13 18:21:11,055 - INFO - PERFORMANCE solution_temple The total process duration was:0.05
# 2024-10-13 18:21:11,055 - INFO - PERFORMANCE solution_temple Stop Time = 2024-10-13 18:21:11
# 2024-10-13 18:21:11,056 - INFO - PERFORMANCE solution_temple Short process duration less than 3 Seconds:0.05
# 2024-10-13 18:21:11,056 - INFO - PERFORMANCE solution_temple Performance optimization is not reccomended
# 2024-10-13 18:21:11,056 - INFO - END solution_temple =============================================

# %% [markdown]
# #### https://github.com/JoeEberle/ -- josepheberle@outlook.com
